# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(Path('../OSU_Bootcamp_Final_Project_Group5/happiness_kcal_by_country.csv'))
df.head()
# Out:
#        country  happiness_score  Alcoholic_Beverages  Animal_Products  \
# 0  Afghanistan            2.523               0.0000           4.7774
# 1      Albania            5.117               0.9120          16.0930
# 2      Algeria            4.887               0.0896           6.0326
# 3    Argentina            5.929               1.4354          14.9869
# 4      Armenia            5.283               0.2274          12.8330
#
#    Animal_fats  Cereal_Excluding_Beer    Eggs  Fish_Seafood  \
# 0       0.8504                37.1186  0.1501        0.0000
# 1       1.0591                16.2107  0.8091        0.1471
# 2       0.1941                25.0112  0.4181        0.1195
# 3       1.0650                16.7927  0.8643        0.2006
# 4       1.7706                19.2658  0.7310        0.1787
#
#    Fruits_Excluding_Wine    Meat  ...  Starchy_Roots  Stimulants  Sugar_Crops  \
# 0                 1.4757  1.2006  ...         0.3252      0.0750          0.0
# ...

# %%
df.dtypes
# Out:
# country                   object
# happiness_score          float64
# Alcoholic_Beverages      float64
# Animal_Products          float64
# Animal_fats              float64
# Cereal_Excluding_Beer    float64
# Eggs                     float64
# Fish_Seafood             float64
# Fruits_Excluding_Wine    float64
# Meat                     float64
# Milk_Excluding_Butter    float64
# Miscellaneous            float64
# Offals                   float64
# Oilcrops                 float64
# Pulses                   float64
# Spices                   float64
# Starchy_Roots            float64
# Stimulants               float64
# Sugar_Crops              float64
# Sugar_Sweeteners         float64
# Treenuts                 float64
# Vegetal_Products         float64
# Vegetable_Oils           float64
# Vegetables               float64
# Obesity                  float64
# Population               float64
# dtype: object

# %%
plt.scatter(df.Alcoholic_Beverages, df.happiness_score)

font1 = {'family':'calibri','color':'green','size':15}
font2 = {'family':'calibri','color':'darkred','size':12}

plt.title('Alcoholic Beverages vs Happiness Score', fontdict = font1)
plt.xlabel('Alcoholic Beverages',fontdict = font2)
plt.ylabel('Happiness Score',fontdict = font2)

plt.savefig('../OSU_Bootcamp_Final_Project_Group5/Images/Charts/Alcoholic_Beverages.png')
plt.show()

# %%
plt.scatter(df.Animal_Products, df.happiness_score)

font1 = {'family':'calibri','color':'green','size':15}
font2 = {'family':'calibri','color':'darkred','size':12}

plt.title('Animal Products vs Happiness Score', fontdict = font1)
plt.xlabel('Animal Products',fontdict = font2)
plt.ylabel('Happiness Score',fontdict = font2)

plt.savefig('../OSU_Bootcamp_Final_Project_Group5/Images/Charts/Animal_Products.png')
plt.show()

# %%
plt.scatter(df.Animal_fats, df.happiness_score)

font1 = {'family':'calibri','color':'green','size':15}
font2 = {'family':'calibri','color':'darkred','size':12}

plt.title('Animal Fats vs Happiness Score', fontdict = font1)
plt.xlabel('Animal Fats',fontdict = font2)
plt.ylabel('Happiness Score',fontdict = font2)

plt.savefig('../OSU_Bootcamp_Final_Project_Group5/Images/Charts/Animal_fats.png')
plt.show()

# %%
plt.scatter(df.Cereal_Excluding_Beer, df.happiness_score)

font1 = {'family':'calibri','color':'green','size':15}
font2 = {'family':'calibri','color':'darkred','size':12}

plt.title('Cereal (Excluding Beer) vs Happiness Score', fontdict = font1)
plt.xlabel('Cereal (Excluding Beer)',fontdict = font2)
plt.ylabel('Happiness Score',fontdict = font2)

plt.savefig('../OSU_Bootcamp_Final_Project_Group5/Images/Charts/Cereal_Excluding_Beer.png')
plt.show()

# %%
plt.scatter(df.Eggs, df.happiness_score)

font1 = {'family':'calibri','color':'green','size':15}
font2 = {'family':'calibri','color':'darkred','size':12}

plt.title('Eggs vs Happiness Score', fontdict = font1)
plt.xlabel('Eggs',fontdict = font2)
plt.ylabel('Happiness Score',fontdict = font2)

plt.savefig('../OSU_Bootcamp_Final_Project_Group5/Images/Charts/Eggs.png')
plt.show()

# %%
plt.scatter(df.Fish_Seafood, df.happiness_score)

font1 = {'family':'calibri','color':'green','size':15}
font2 = {'family':'calibri','color':'darkred','size':12}

plt.title('Fish Seafood vs Happiness Score', fontdict = font1)
plt.xlabel('Fish Seafood',fontdict = font2)
plt.ylabel('Happiness Score',fontdict = font2)

plt.savefig('Charts/Fish_Seafood.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12380\4270584807.py in <module>
#       8 plt.ylabel('Happiness Score',fontdict = font2)
#       9
# ---> 10 plt.savefig('Charts/Fish_Seafood.png')
#      11 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     977 def savefig(*args, **kwargs):
#     978     fig = gcf()
# --> 979     res = fig.savefig(*args, **kwargs)
#     980     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     981     return res
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    3044                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3045
# -> 3046             self.canvas.print_figure(fname, **kwargs)
#    3047
# ...

# %%
plt.scatter(df.Meat, df.happiness_score)

font1 = {'family':'calibri','color':'green','size':15}
font2 = {'family':'calibri','color':'darkred','size':12}

plt.title('Meat vs Happiness Score', fontdict = font1)
plt.xlabel('Meat',fontdict = font2)
plt.ylabel('Happiness Score',fontdict = font2)

plt.savefig('../OSU_Bootcamp_Final_Project_Group5/Images/Charts/Meat.png')
plt.show()

# %%
plt.scatter(df.Milk_Excluding_Butter, df.happiness_score)

font1 = {'family':'calibri','color':'green','size':15}
font2 = {'family':'calibri','color':'darkred','size':12}

plt.title('Milk_Excluding_Butter vs Happiness Score', fontdict = font1)
plt.xlabel('Milk_Excluding_Butter',fontdict = font2)
plt.ylabel('Happiness Score',fontdict = font2)

plt.savefig('../OSU_Bootcamp_Final_Project_Group5/Images/Charts/Milk_Excluding_Butter.png')
plt.show()

# %%
plt.scatter(df.Miscellaneous, df.happiness_score)

font1 = {'family':'calibri','color':'green','size':15}
font2 = {'family':'calibri','color':'darkred','size':12}

plt.title('Miscellaneous vs Happiness Score', fontdict = font1)
plt.xlabel('Miscellaneous',fontdict = font2)
plt.ylabel('Happiness Score',fontdict = font2)

plt.savefig('../OSU_Bootcamp_Final_Project_Group5/Images/Charts/Miscellaneous.png')
plt.show()

# %%
plt.scatter(df.Offals, df.happiness_score)

font1 = {'family':'calibri','color':'green','size':15}
font2 = {'family':'calibri','color':'darkred','size':12}

plt.title('Offals vs Happiness Score', fontdict = font1)
plt.xlabel('Offals',fontdict = font2)
plt.ylabel('Happiness Score',fontdict = font2)

plt.savefig('../OSU_Bootcamp_Final_Project_Group5/Images/Charts/Offals.png')
plt.show()

# %%
plt.scatter(df.Oilcrops, df.happiness_score)

font1 = {'family':'calibri','color':'green','size':15}
font2 = {'family':'calibri','color':'darkred','size':12}

plt.title('Oilcrops vs Happiness Score', fontdict = font1)
plt.xlabel('Oilcrops',fontdict = font2)
plt.ylabel('Happiness Score',fontdict = font2)

plt.savefig('../OSU_Bootcamp_Final_Project_Group5/Images/Charts/Oilcrops.png')
plt.show()

# %%
plt.scatter(df.Pulses, df.happiness_score)

font1 = {'family':'calibri','color':'green','size':15}
font2 = {'family':'calibri','color':'darkred','size':12}

plt.title('Pulses vs Happiness Score', fontdict = font1)
plt.xlabel('Pulses',fontdict = font2)
plt.ylabel('Happiness Score',fontdict = font2)

plt.savefig('../OSU_Bootcamp_Final_Project_Group5/Images/Charts/Pulses.png')
plt.show()

# %%
plt.scatter(df.Spices, df.happiness_score)

font1 = {'family':'calibri','color':'green','size':15}
font2 = {'family':'calibri','color':'darkred','size':12}

plt.title('Spices vs Happiness Score', fontdict = font1)
plt.xlabel('Spices',fontdict = font2)
plt.ylabel('Happiness Score',fontdict = font2)

plt.savefig('../OSU_Bootcamp_Final_Project_Group5/Images/Charts/Spices.png')
plt.show()

# %%
plt.scatter(df.Starchy_Roots, df.happiness_score)

font1 = {'family':'calibri','color':'green','size':15}
font2 = {'family':'calibri','color':'darkred','size':12}

plt.title('Starchy_Roots vs Happiness Score', fontdict = font1)
plt.xlabel('Starchy_Roots',fontdict = font2)
plt.ylabel('Happiness Score',fontdict = font2)

plt.savefig('../OSU_Bootcamp_Final_Project_Group5/Images/Charts/Starchy_Roots.png')
plt.show()

# %%
plt.scatter(df.Stimulants, df.happiness_score)

font1 = {'family':'calibri','color':'green','size':15}
font2 = {'family':'calibri','color':'darkred','size':12}

plt.title('Stimulants vs Happiness Score', fontdict = font1)
plt.xlabel('Stimulants',fontdict = font2)
plt.ylabel('Happiness Score',fontdict = font2)

plt.savefig('../OSU_Bootcamp_Final_Project_Group5/Images/Charts/Stimulants.png')
plt.show()

# %%
plt.scatter(df.Sugar_Crops, df.happiness_score)

font1 = {'family':'calibri','color':'green','size':15}
font2 = {'family':'calibri','color':'darkred','size':12}

plt.title('Sugar_Crops vs Happiness Score', fontdict = font1)
plt.xlabel('Sugar_Crops',fontdict = font2)
plt.ylabel('Happiness Score',fontdict = font2)

plt.savefig('../OSU_Bootcamp_Final_Project_Group5/Images/Charts/Sugar_Crops.png')
plt.show()

# %%
plt.scatter(df.Sugar_Sweeteners, df.happiness_score)

font1 = {'family':'calibri','color':'green','size':15}
font2 = {'family':'calibri','color':'darkred','size':12}

plt.title('Sugar_Sweeteners vs Happiness Score', fontdict = font1)
plt.xlabel('Sugar_Sweeteners',fontdict = font2)
plt.ylabel('Happiness Score',fontdict = font2)

plt.savefig('../OSU_Bootcamp_Final_Project_Group5/Images/Charts/Sugar_Sweeteners.png')
plt.show()

# %%
plt.scatter(df.Treenuts, df.happiness_score)

font1 = {'family':'calibri','color':'green','size':15}
font2 = {'family':'calibri','color':'darkred','size':12}

plt.title('Treenuts vs Happiness Score', fontdict = font1)
plt.xlabel('Treenuts',fontdict = font2)
plt.ylabel('Happiness Score',fontdict = font2)

plt.savefig('../OSU_Bootcamp_Final_Project_Group5/Images/Charts/Treenuts.png')
plt.show()

# %%
plt.scatter(df.Vegetal_Products, df.happiness_score)

font1 = {'family':'calibri','color':'green','size':15}
font2 = {'family':'calibri','color':'darkred','size':12}

plt.title('Vegetal_Products vs Happiness Score', fontdict = font1)
plt.xlabel('Vegetal_Products',fontdict = font2)
plt.ylabel('Happiness Score',fontdict = font2)

plt.savefig('../OSU_Bootcamp_Final_Project_Group5/Images/Charts/Vegetal_Products.png')
plt.show()

# %%
plt.scatter(df.Vegetable_Oils, df.happiness_score)

font1 = {'family':'calibri','color':'green','size':15}
font2 = {'family':'calibri','color':'darkred','size':12}

plt.title('Vegetable_Oils vs Happiness Score', fontdict = font1)
plt.xlabel('Vegetable_Oils',fontdict = font2)
plt.ylabel('Happiness Score',fontdict = font2)

plt.savefig('../OSU_Bootcamp_Final_Project_Group5/Images/Charts/Vegetable_Oils.png')
plt.show()

# %%
plt.scatter(df.Vegetables, df.happiness_score)

font1 = {'family':'calibri','color':'green','size':15}
font2 = {'family':'calibri','color':'darkred','size':12}

plt.title('Vegetables vs Happiness Score', fontdict = font1)
plt.xlabel('Vegetables',fontdict = font2)
plt.ylabel('Happiness Score',fontdict = font2)

plt.savefig('../OSU_Bootcamp_Final_Project_Group5/Images/Charts/Vegetables.png')
plt.show()

# %%
plt.scatter(df.Obesity, df.happiness_score)

font1 = {'family':'calibri','color':'green','size':15}
font2 = {'family':'calibri','color':'darkred','size':12}

plt.title('Obesity vs Happiness Score', fontdict = font1)
plt.xlabel('Obesity',fontdict = font2)
plt.ylabel('Happiness Score',fontdict = font2)

plt.savefig('../OSU_Bootcamp_Final_Project_Group5/Images/Charts/Obesity.png')
plt.show()

# %%
plt.scatter(df.Population, df.happiness_score)

font1 = {'family':'calibri','color':'green','size':15}
font2 = {'family':'calibri','color':'darkred','size':12}

plt.title('Population vs Happiness Score', fontdict = font1)
plt.xlabel('Population',fontdict = font2)
plt.ylabel('Happiness Score',fontdict = font2)

plt.savefig('../OSU_Bootcamp_Final_Project_Group5/Images/Charts/Population.png')
plt.show()
