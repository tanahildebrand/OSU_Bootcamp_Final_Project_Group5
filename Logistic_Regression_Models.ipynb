# %% [markdown]
# # Supervised Learning for World Happiness based on Dietary Dataset

# %% [markdown]
# ### Importing dependencies

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %% [markdown]
# ### Loading the DataFrame

# %%
# Loading the data
file_path = Path('happiness_kcal_by_country.csv')
df = pd.read_csv(file_path)
df
# Out:
#                                 country  happiness_score  Alcoholic_Beverages  \
# 0                           Afghanistan            2.523               0.0000
# 1                               Albania            5.117               0.9120
# 2                               Algeria            4.887               0.0896
# 3                             Argentina            5.929               1.4354
# 4                               Armenia            5.283               0.2274
# ..                                  ...              ...                  ...
# 132  Venezuela (Bolivarian Republic of)            4.892               0.8454
# 133                             Vietnam            5.411               0.7150
# 134                               Yemen            3.658               0.0000
# 135                              Zambia            4.073               1.1925
# 136                            Zimbabwe            3.145               1.4269
#
#      Animal_Products  Animal_fats  Cereal_Excluding_Beer    Eggs  \
# 0             4.7774       0.8504                37.1186  0.1501
# 1            16.0930       1.0591                16.2107  0.8091
# 2             6.0326       0.1941                25.0112  0.4181
# 3            14.9869       1.0650                16.7927  0.8643
# 4            12.8330       1.7706                19.2658  0.7310
# ..               ...          ...                    ...     ...
# 132           7.2303       0.6007                21.3126  0.2892
# 133          10.9806       0.9363                26.9833  0.2894
# 134           3.4667       0.3394                32.0727  0.1455
# 135           3.3043       0.3230                31.5528  0.1988
# 136           3.9356       0.6904                29.8044  0.1381
#
#      Fish_Seafood  Fruits_Excluding_Wine    Meat  ...  Spices  Starchy_Roots  \
# 0          0.0000                 1.4757  1.2006  ...  0.1001         0.3252
# 1          0.1471                 3.8982  3.8688  ...  0.0000         1.2651
# 2          0.1195                 3.1805  1.2543  ...  0.1195         1.9262
# 3          0.2006                 1.4663  9.4459  ...  0.0309         1.4045
# 4          0.1787                 2.5341  4.2235  ...  0.0162         1.2508
# ..            ...                    ...     ...  ...     ...            ...
# 132        0.4449                 2.3804  3.1368  ...  0.0000         1.3571
# 133        1.0385                 1.8046  7.8311  ...  0.4256         0.7150
# 134        0.1697                 1.1879  2.0121  ...  0.0485         0.3152
# 135        0.5714                 0.2236  1.5155  ...  0.0745         4.0994
# 136        0.1611                 0.4373  1.7491  ...  0.0460         1.2888
#
#      Stimulants  Sugar_Crops  Treenuts  Vegetal_Products  Vegetable_Oils  \
# 0        0.0750       0.0000    0.1251           45.2476          2.3012
# 1        0.2501       0.0000    0.3972           33.9070          2.8244
# 2        0.1493       0.0000    0.2240           43.9749          5.7638
# 3        0.2315       0.0000    0.0463           34.9900          5.5410
# 4        0.6985       0.0000    0.3086           37.1670          3.5737
# ..          ...          ...       ...               ...             ...
# 132      0.0667       0.0000    0.0000           42.7586          7.5417
# 133      0.1021       0.1532    0.3575           39.0364          1.3279
# 134      0.1212       0.0000    0.0242           46.5455          3.9515
# 135      0.0248       0.0000    0.0000           46.7081          3.0062
# 136      0.0460       0.0000    0.1151           46.0759          6.2601
#
#      Vegtables  Obesity  Population
# 0       0.7504      4.5  38928000.0
# 1       2.7508     22.3   2838000.0
# 2       2.0457     26.6  44357000.0
# 3       0.8643     28.5  45377000.0
# 4       3.2164     20.9   2956000.0
# ..         ...      ...         ...
# 132     0.6674     25.2  28645000.0
# 133     1.9578      2.1  96209000.0
# 134     0.3636     14.1  29826000.0
# 135     0.4472      6.5  18384000.0
# 136     0.2532     12.3  14863000.0
#
# [137 rows x 25 columns]

# %% [markdown]
# ### Binning Happiness data into categories: Happy and Unhappy.

# %%
happiness= pd.cut(df.happiness_score,bins=[0,4.99,10],labels=['Unhappy','Happy'])
happiness
# Out:
# 0      Unhappy
# 1        Happy
# 2      Unhappy
# 3        Happy
# 4        Happy
#         ...
# 132    Unhappy
# 133      Happy
# 134    Unhappy
# 135    Unhappy
# 136    Unhappy
# Name: happiness_score, Length: 137, dtype: category
# Categories (2, object): ['Unhappy' < 'Happy']

# %%
# Adding Happiness column to the DataFrame
df.insert(1, 'Happiness', happiness)
df.head(10)
# Out:
#        country Happiness  happiness_score  Alcoholic_Beverages  \
# 0  Afghanistan   Unhappy            2.523               0.0000
# 1      Albania     Happy            5.117               0.9120
# 2      Algeria   Unhappy            4.887               0.0896
# 3    Argentina     Happy            5.929               1.4354
# 4      Armenia     Happy            5.283               0.2274
# 5    Australia     Happy            7.183               1.9783
# 6      Austria     Happy            7.268               2.8161
# 7   Azerbaijan     Happy            5.171               2.2555
# 8   Bangladesh     Happy            5.025               0.0000
# 9      Belarus     Happy            5.534               3.2979
#
#    Animal_Products  Animal_fats  Cereal_Excluding_Beer    Eggs  Fish_Seafood  \
# 0           4.7774       0.8504                37.1186  0.1501        0.0000
# 1          16.0930       1.0591                16.2107  0.8091        0.1471
# 2           6.0326       0.1941                25.0112  0.4181        0.1195
# 3          14.9869       1.0650                16.7927  0.8643        0.2006
# 4          12.8330       1.7706                19.2658  0.7310        0.1787
# 5          15.6146       1.9027                11.6430  0.4681        0.6040
# 6          15.6106       5.2532                12.3748  0.7853        0.4062
# 7           8.1682       1.3050                28.7417  0.5478        0.0967
# 8           2.3695       0.1541                37.5265  0.2312        0.8284
# 9          12.2644       2.6748                14.2705  0.8511        0.4863
#
#    Fruits_Excluding_Wine  ...  Spices  Starchy_Roots  Stimulants  Sugar_Crops  \
# 0                 1.4757  ...  0.1001         0.3252      0.0750       0.0000
# 1                 3.8982  ...  0.0000         1.2651      0.2501       0.0000
# 2                 3.1805  ...  0.1195         1.9262      0.1493       0.0000
# 3                 1.4663  ...  0.0309         1.4045      0.2315       0.0000
# 4                 2.5341  ...  0.0162         1.2508      0.6985       0.0000
# 5                 1.6611  ...  0.1057         1.3138      0.5134       0.0000
# 6                 1.5976  ...  0.1083         1.4622      0.3656       0.0000
# 7                 1.6111  ...  0.0161         2.2072      0.3061       0.0000
# 8                 0.6550  ...  0.5009         1.9264      0.0193       0.0193
# 9                 1.3982  ...  0.0152         4.9848      0.3951       0.0000
#
#    Treenuts  Vegetal_Products  Vegetable_Oils  Vegtables  Obesity   Population
# 0    0.1251           45.2476          2.3012     0.7504      4.5   38928000.0
# 1    0.3972           33.9070          2.8244     2.7508     22.3    2838000.0
# 2    0.2240           43.9749          5.7638     2.0457     26.6   44357000.0
# 3    0.0463           34.9900          5.5410     0.8643     28.5   45377000.0
# 4    0.3086           37.1670          3.5737     3.2164     20.9    2956000.0
# 5    0.8457           34.3854          8.3812     1.1326     30.4   25754000.0
# 6    0.4197           34.3894          7.1622     1.0290     21.9    8914000.0
# 7    0.4511           41.8237          1.2083     1.4661     19.9   10108000.0
# 8    0.1156           47.6401          3.4290     0.6165      3.4  169809000.0
# 9    0.4255           37.7204          6.1246     1.8389     26.6    9375000.0
#
# [10 rows x 26 columns]

# %%
# Dropping unhelpful columns
# 'country' is a string column/label
# 'happiness_score' is redundant
# 'Population' is not a dietary dataset
df=df.drop(columns=['country', 'happiness_score', 'Population'], axis=1)
df.head(10)
# Out:
#   Happiness  Alcoholic_Beverages  Animal_Products  Animal_fats  \
# 0   Unhappy               0.0000           4.7774       0.8504
# 1     Happy               0.9120          16.0930       1.0591
# 2   Unhappy               0.0896           6.0326       0.1941
# 3     Happy               1.4354          14.9869       1.0650
# 4     Happy               0.2274          12.8330       1.7706
# 5     Happy               1.9783          15.6146       1.9027
# 6     Happy               2.8161          15.6106       5.2532
# 7     Happy               2.2555           8.1682       1.3050
# 8     Happy               0.0000           2.3695       0.1541
# 9     Happy               3.2979          12.2644       2.6748
#
#    Cereal_Excluding_Beer    Eggs  Fish_Seafood  Fruits_Excluding_Wine    Meat  \
# 0                37.1186  0.1501        0.0000                 1.4757  1.2006
# 1                16.2107  0.8091        0.1471                 3.8982  3.8688
# 2                25.0112  0.4181        0.1195                 3.1805  1.2543
# 3                16.7927  0.8643        0.2006                 1.4663  9.4459
# 4                19.2658  0.7310        0.1787                 2.5341  4.2235
# 5                11.6430  0.4681        0.6040                 1.6611  7.4902
# 6                12.3748  0.7853        0.4062                 1.5976  5.0095
# 7                28.7417  0.5478        0.0967                 1.6111  2.9322
# 8                37.5265  0.2312        0.8284                 0.6550  0.3468
# 9                14.2705  0.8511        0.4863                 1.3982  5.7143
#
#    Milk_Excluding_Butter  ...  Pulses  Spices  Starchy_Roots  Stimulants  \
# 0                 2.4512  ...  0.5003  0.1001         0.3252      0.0750
# 1                 9.9441  ...  0.8091  0.0000         1.2651      0.2501
# 2                 3.9869  ...  1.0900  0.1195         1.9262      0.1493
# 3                 3.1641  ...  0.1235  0.0309         1.4045      0.2315
# 4                 5.6368  ...  0.4386  0.0162         1.2508      0.6985
# 5                 4.8022  ...  0.1359  0.1057         1.3138      0.5134
# 6                 4.0482  ...  0.1083  0.1083         1.4622      0.3656
# 7                 3.1738  ...  0.0806  0.0161         2.2072      0.3061
# 8                 0.7706  ...  1.2329  0.5009         1.9264      0.0193
# 9                 2.1884  ...  0.0000  0.0152         4.9848      0.3951
#
#    Sugar_Crops  Treenuts  Vegetal_Products  Vegetable_Oils  Vegtables  Obesity
# 0       0.0000    0.1251           45.2476          2.3012     0.7504      4.5
# 1       0.0000    0.3972           33.9070          2.8244     2.7508     22.3
# 2       0.0000    0.2240           43.9749          5.7638     2.0457     26.6
# 3       0.0000    0.0463           34.9900          5.5410     0.8643     28.5
# 4       0.0000    0.3086           37.1670          3.5737     3.2164     20.9
# 5       0.0000    0.8457           34.3854          8.3812     1.1326     30.4
# 6       0.0000    0.4197           34.3894          7.1622     1.0290     21.9
# 7       0.0000    0.4511           41.8237          1.2083     1.4661     19.9
# 8       0.0193    0.1156           47.6401          3.4290     0.6165      3.4
# 9       0.0000    0.4255           37.7204          6.1246     1.8389     26.6
#
# [10 rows x 23 columns]

# %%
# Create our features
X = pd.get_dummies(df.drop('Happiness', axis=1))

# Create our target
y = df['Happiness']

# %%
X.describe()
# Out:
#        Alcoholic_Beverages  Animal_Products  Animal_fats  \
# count           137.000000       137.000000   137.000000
# mean              1.374335         9.418774     1.360410
# std               1.115354         4.908184     1.373477
# min               0.000000         1.623700     0.000000
# 25%               0.355200         5.183100     0.404600
# 50%               1.276800         9.172700     0.932200
# 75%               2.061700        13.206100     1.974100
# max               5.157400        22.291100     7.800700
#
#        Cereal_Excluding_Beer        Eggs  Fish_Seafood  Fruits_Excluding_Wine  \
# count             137.000000  137.000000    137.000000             137.000000
# mean               20.808085    0.464232      0.575042               1.864257
# std                 6.604714    0.312974      0.567862               1.276899
# min                 9.437800    0.018800      0.000000               0.147100
# 25%                14.754600    0.151900      0.221100               1.183500
# 50%                20.584700    0.446400      0.406200               1.603200
# 75%                25.605300    0.666100      0.795100               2.219500
# max                37.526500    1.446100      4.418300               8.805600
#
#              Meat  Milk_Excluding_Butter  Miscellaneous  ...      Pulses  \
# count  137.000000             137.000000     137.000000  ...  137.000000
# mean     3.782418               3.085221       0.121138  ...    1.075519
# std      2.200806               2.081442       0.161789  ...    1.239935
# min      0.298000               0.132200       0.000000  ...    0.000000
# 25%      2.012100               1.142300       0.021500  ...    0.290000
# 50%      3.524700               2.961400       0.074200  ...    0.662400
# 75%      5.218100               4.569800       0.164000  ...    1.498700
# max     10.567400               9.944100       1.182200  ...    7.563800
#
#            Spices  Starchy_Roots  Stimulants  Sugar_Crops    Treenuts  \
# count  137.000000     137.000000  137.000000   137.000000  137.000000
# mean     0.180331       2.825885    0.315014     0.019878    0.288201
# std      0.246362       3.552728    0.333263     0.077923    0.290579
# min      0.000000       0.293800    0.000000     0.000000    0.000000
# 25%      0.036100       1.075300    0.077300     0.000000    0.060200
# 50%      0.083700       1.501900    0.182700     0.000000    0.204100
# 75%      0.201600       2.670900    0.435600     0.000000    0.421600
# max      1.220200      19.614300    2.009000     0.593000    1.421000
#
#        Vegetal_Products  Vegetable_Oils   Vegtables     Obesity
# count        137.000000      137.000000  137.000000  137.000000
# mean          40.582210        4.990855    1.124566   18.410949
# std            4.907847        2.293868    0.656202    9.515125
# min           27.708900        0.932500    0.095700    0.000000
# 25%           36.801600        3.123900    0.612200    8.200000
# 50%           40.841800        4.646100    1.033900   21.300000
# 75%           44.840700        6.665700    1.466100   25.700000
# max           48.386400       10.383900    3.352400   37.300000
#
# [8 rows x 22 columns]

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# Happy      93
# Unhappy    44
# Name: Happiness, dtype: int64

# %% [markdown]
# ### Training Dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
Counter(y_train)
# Out:
# Counter({'Unhappy': 31, 'Happy': 71})

# %% [markdown]
# ### BalancedRandomForestClassifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
# YOUR CODE HERE
# Creating the decision tree classifier instance.
from imblearn.ensemble import BalancedRandomForestClassifier
model_brfc = BalancedRandomForestClassifier(n_estimators=100, random_state=1)
# Fitting the model.
model_brfc.fit(X_train, y_train)
y_pred_brfc = model_brfc.predict(X_test)

# %%
# Calculated the balanced accuracy score
# YOUR CODE HERE
balanced_accuracy_score(y_test, y_pred_brfc)
# Out:
# 0.763986013986014

# %%
# Display the confusion matrix
# YOUR CODE HERE
cm_brfc = confusion_matrix(y_test, y_pred_brfc)
cm_brfc_df = pd.DataFrame(cm_brfc, index=['actual_happy', 'actual_unhappy'], columns=['predicted_happy', 'predicted_unhappy'])
cm_brfc_df
# Out:
#                 predicted_happy  predicted_unhappy
# actual_happy                 15                  7
# actual_unhappy                2                 11

# %%
# Print the imbalanced classification report
# YOUR CODE HERE
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred_brfc))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#       Happy       0.88      0.68      0.85      0.77      0.76      0.57        22
#     Unhappy       0.61      0.85      0.68      0.71      0.76      0.59        13
#
# avg / total       0.78      0.74      0.79      0.75      0.76      0.57        35

# %% [markdown]
# ### Feature Importance

# %%
# List the features sorted in descending order by feature importance
# YOUR CODE HERE
importance = sorted(zip(model_brfc.feature_importances_, X.columns), reverse=True)
importance
# Out:
# [(0.149442929799742, 'Vegetal_Products'),
#  (0.12961676682348552, 'Animal_Products'),
#  (0.09843198939467887, 'Eggs'),
#  (0.07590682403510633, 'Animal_fats'),
#  (0.06992262812975143, 'Meat'),
#  (0.05864068976220862, 'Cereal_Excluding_Beer'),
#  (0.05416890965606372, 'Alcoholic_Beverages'),
#  (0.04767027431817313, 'Stimulants'),
#  (0.03722386608824089, 'Milk_Excluding_Butter'),
#  (0.035051756694154064, 'Starchy_Roots'),
#  (0.03418295753778202, 'Oilcrops'),
#  (0.0324013711034197, 'Obesity'),
#  (0.02876545798429756, 'Vegtables'),
#  (0.028384793237279826, 'Fish_Seafood'),
#  (0.025606041313795055, 'Fruits_Excluding_Wine'),
#  (0.018877036086403464, 'Pulses'),
#  (0.017838183639324184, 'Spices'),
#  (0.015528986657952406, 'Vegetable_Oils'),
#  (0.013477005358437983, 'Offals'),
#  (0.013237050590880753, 'Treenuts'),
#  (0.010049484124381326, 'Miscellaneous'),
#  (0.005574997664441131, 'Sugar_Crops')]

# %% [markdown]
# ### EasyEnsembleClassifier

# %%
# Train the EasyEnsembleClassifier
# YOUR CODE HERE
from imblearn.ensemble import EasyEnsembleClassifier
model_eec = EasyEnsembleClassifier(n_estimators=100, random_state=1)
model_eec.fit(X_train, y_train)
y_pred_eec = model_eec.predict(X_test)

# %%
# Calculated the balanced accuracy score
# YOUR CODE HERE
bal_acc_score_eec = balanced_accuracy_score(y_test, y_pred_eec)
print(bal_acc_score_eec)
# Out:
# 0.763986013986014

# %%
# Display the confusion matrix
# YOUR CODE HERE
cm_eec = confusion_matrix(y_test, y_pred_eec)
cm_eec_df = pd.DataFrame(cm_eec, index=['actual_happy', 'actual_unhappy'], columns=['predicted_happy', 'predicted_unhappy'])
cm_eec_df
# Out:
#                 predicted_happy  predicted_unhappy
# actual_happy                 15                  7
# actual_unhappy                2                 11

# %%
# Print the imbalanced classification report
# YOUR CODE HERE
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred_eec))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#       Happy       0.88      0.68      0.85      0.77      0.76      0.57        22
#     Unhappy       0.61      0.85      0.68      0.71      0.76      0.59        13
#
# avg / total       0.78      0.74      0.79      0.75      0.76      0.57        35

# %% [markdown]
# ### RandomOverSampler

# %%
# Resample the training data with the RandomOversampler
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=1)
X_resampled, y_resampled = ros.fit_resample(X_train, y_train)
Counter(y_resampled)
# Out:
# Counter({'Unhappy': 71, 'Happy': 71})

# %%
# Train the Logistic Regression model using the resampled data
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='lbfgs', random_state=1)
model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=1)

# %%
# Calculated the balanced accuracy score
y_pred = model.predict(X_test)
from sklearn.metrics import balanced_accuracy_score
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.7255244755244755

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm_df = pd.DataFrame(cm, index=['actual_happy', 'actual_unhappy'],  columns=['predicted_happy', 'predicted_unhappy'])
cm_df
# Out:
#                 predicted_happy  predicted_unhappy
# actual_happy                 15                  7
# actual_unhappy                3                 10

# %%
# Print the imbalanced classification report
# YOUR CODE HERE
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#       Happy       0.83      0.68      0.77      0.75      0.72      0.52        22
#     Unhappy       0.59      0.77      0.68      0.67      0.72      0.53        13
#
# avg / total       0.74      0.71      0.74      0.72      0.72      0.52        35

# %% [markdown]
# ### SMOTE

# %%
# Resample the training data with SMOTE
# YOUR CODE HERE
from imblearn.over_sampling import SMOTE
X_resampled, y_resampled = SMOTE(random_state=1,
sampling_strategy='auto').fit_resample(
   X_train, y_train)

# %%
# Train the Logistic Regression model using the resampled data
# YOUR CODE HERE
model = LogisticRegression(solver='lbfgs', random_state=1)
model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=1)

# %%
# Calculated the balanced accuracy score
# YOUR CODE HERE
y_pred = model.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.7797202797202798

# %%
# Display the confusion matrix
# YOUR CODE HERE
cm_smote = confusion_matrix(y_test, y_pred)
cm_smote_df = pd.DataFrame(cm_smote, index=['actual_happy', 'actual_unhappy'], columns = ['predicted_happy', 'predicted_unhappy'])
cm_smote_df
# Out:
#                 predicted_happy  predicted_unhappy
# actual_happy                 14                  8
# actual_unhappy                1                 12

# %%
# Print the imbalanced classification report
# YOUR CODE HERE
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#       Happy       0.93      0.64      0.92      0.76      0.77      0.57        22
#     Unhappy       0.60      0.92      0.64      0.73      0.77      0.60        13
#
# avg / total       0.81      0.74      0.82      0.75      0.77      0.58        35

# %% [markdown]
# ### ClusterCentroids Resampler

# %%
# Resample the data using the ClusterCentroids resampler
# Warning: This is a large dataset, and this step may take some time to complete
# YOUR CODE HERE
from imblearn.under_sampling import ClusterCentroids
cc = ClusterCentroids(random_state=1)
X_resampled, y_resampled = cc.fit_resample(X_train, y_train)

# %%
# Train the Logistic Regression model using the resampled data
# YOUR CODE HERE
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='lbfgs', random_state=1)
model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=1)

# %%
# Calculated the balanced accuracy score
# YOUR CODE HERE
from sklearn.metrics import balanced_accuracy_score
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.7797202797202798

# %%
# Display the confusion matrix
# YOUR CODE HERE
from sklearn.metrics import confusion_matrix
y_pred = model.predict(X_test)
cm_cluster_centroids = confusion_matrix(y_test, y_pred)
cm_cluster_centroids_df = pd.DataFrame(cm_cluster_centroids, index=['actual_happy', 'actual_unhappy'], columns=['predicted_happy', 'predicted_unhappy'])
cm_cluster_centroids_df
# Out:
#                 predicted_happy  predicted_unhappy
# actual_happy                 15                  7
# actual_unhappy                2                 11

# %%
# Print the imbalanced classification report
# YOUR CODE HERE
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#       Happy       0.88      0.68      0.85      0.77      0.76      0.57        22
#     Unhappy       0.61      0.85      0.68      0.71      0.76      0.59        13
#
# avg / total       0.78      0.74      0.79      0.75      0.76      0.57        35

# %% [markdown]
# ### SMOTEENN

# %%
# Resample the training data with SMOTEENN
# Warning: This is a large dataset, and this step may take some time to complete
# YOUR CODE HERE
from imblearn.combine import SMOTEENN
smote_enn = SMOTEENN(random_state=1)
X_resampled, y_resampled = smote_enn.fit_resample(X, y)

# %%
# Train the Logistic Regression model using the resampled data
# YOUR CODE HERE
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='lbfgs', random_state=1)
model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=1)

# %%
# Calculated the balanced accuracy score
# YOUR CODE HERE
from sklearn.metrics import balanced_accuracy_score
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.763986013986014

# %%
# Display the confusion matrix
# YOUR CODE HERE
from sklearn.metrics import confusion_matrix
y_pred = model.predict(X_test)
cm_smoteenn = confusion_matrix(y_test, y_pred)
cm_smoteenn_df = pd.DataFrame(cm_smoteenn, index=['actual_happy', 'actual_unhappy'], columns = ['predicted_happy', 'predicted_unhappy'])
cm_smoteenn_df
# Out:
#                 predicted_happy  predicted_unhappy
# actual_happy                 15                  7
# actual_unhappy                3                 10

# %%
# Print the imbalanced classification report
# YOUR CODE HERE
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#       Happy       0.83      0.68      0.77      0.75      0.72      0.52        22
#     Unhappy       0.59      0.77      0.68      0.67      0.72      0.53        13
#
# avg / total       0.74      0.71      0.74      0.72      0.72      0.52        35
