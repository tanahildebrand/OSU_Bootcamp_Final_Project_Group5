# %%
import pandas as pd

# %%
file_path = "Resources/Food_Supply_kcal_Data.csv"
food_supplykcal_df = pd.read_csv(file_path)
food_supplykcal_df.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan               0.0000           4.7774       0.8504
# 1              Albania               0.9120          16.0930       1.0591
# 2              Algeria               0.0896           6.0326       0.1941
# 3               Angola               1.9388           4.6927       0.2644
# 4  Antigua and Barbuda               2.3041          15.3672       1.5429
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                   37.1186  0.1501         0.0000
# 1                      0.0                   16.2107  0.8091         0.1471
# 2                      0.0                   25.0112  0.4181         0.1195
# 3                      0.0                   18.3521  0.0441         0.8372
# 4                      0.0                   13.7215  0.2057         1.7280
#
# ...

# %%
food_supplykcal_df.describe()
# Out:
#        Alcoholic Beverages  Animal Products  Animal fats  \
# count           170.000000       170.000000   170.000000
# mean              1.325197         9.294553     1.267419
# std               1.062362         4.754174     1.283723
# min               0.000000         1.623700     0.000000
# 25%               0.361300         5.082600     0.342850
# 50%               1.244600         9.034100     0.877500
# 75%               2.028050        13.174975     1.763175
# max               5.157400        22.291100     7.800700
#
#        Aquatic Products, Other  Cereals - Excluding Beer        Eggs  \
# count               170.000000                170.000000  170.000000
# mean                  0.002786                 20.365358    0.428504
# std                   0.030879                  6.467936    0.304333
# min                   0.000000                  8.956500    0.018800
# 25%                   0.000000                 15.306175    0.141000
# ...

# %%
food_supplykcal_df.dtypes
# Out:
# Country                          object
# Alcoholic Beverages             float64
# Animal Products                 float64
# Animal fats                     float64
# Aquatic Products, Other         float64
# Cereals - Excluding Beer        float64
# Eggs                            float64
# Fish, Seafood                   float64
# Fruits - Excluding Wine         float64
# Meat                            float64
# Milk - Excluding Butter         float64
# Miscellaneous                   float64
# Offals                          float64
# Oilcrops                        float64
# Pulses                          float64
# Spices                          float64
# Starchy Roots                   float64
# Stimulants                      float64
# Sugar Crops                     float64
# Sugar & Sweeteners              float64
# Treenuts                        float64
# Vegetal Products                float64
# Vegetable Oils                  float64
# ...

# %%
kcal_df = food_supplykcal_df.drop(["Undernourished","Unit (all except Population)","Confirmed", "Deaths", "Recovered","Active","Aquatic Products, Other"],axis=1)

# %%
kcal_df.isnull().sum()
# Out:
# Country                     0
# Alcoholic Beverages         0
# Animal Products             0
# Animal fats                 0
# Cereals - Excluding Beer    0
# Eggs                        0
# Fish, Seafood               0
# Fruits - Excluding Wine     0
# Meat                        0
# Milk - Excluding Butter     0
# Miscellaneous               0
# Offals                      0
# Oilcrops                    0
# Pulses                      0
# Spices                      0
# Starchy Roots               0
# Stimulants                  0
# Sugar Crops                 0
# Sugar & Sweeteners          0
# Treenuts                    0
# Vegetal Products            0
# Vegetable Oils              0
# Vegetables                  0
# Obesity                     3
# Population                  0
# dtype: int64

# %%
kcal_df.dropna()
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000           4.7774
# 1                               Albania               0.9120          16.0930
# 2                               Algeria               0.0896           6.0326
# 3                                Angola               1.9388           4.6927
# 4                   Antigua and Barbuda               2.3041          15.3672
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.8454           7.2303
# 166                             Vietnam               0.7150          10.9806
# 167                               Yemen               0.0000           3.4667
# 168                              Zambia               1.1925           3.3043
# 169                            Zimbabwe               1.4269           3.9356
#
# ...

# %%
kcal_df.to_csv("kcal_df.csv")
