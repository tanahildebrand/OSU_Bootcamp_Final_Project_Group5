# %%
import pandas as pd

# %%
file_path = "Resources/2022.csv"
happiness_df = pd.read_csv(file_path)
happiness_df.head()
# Out:
#    RANK      Country Happiness score Whisker-high Whisker-low  \
# 0     1      Finland           7,821        7,886       7,756
# 1     2      Denmark           7,636        7,710       7,563
# 2     3      Iceland           7,557        7,651       7,464
# 3     4  Switzerland           7,512        7,586       7,437
# 4     5  Netherlands           7,415        7,471       7,359
#
#   Dystopia (1.83) + residual Explained by: GDP per capita  \
# 0                      2,518                        1,892
# 1                      2,226                        1,953
# 2                      2,320                        1,936
# 3                      2,153                        2,026
# 4                      2,137                        1,945
#
#   Explained by: Social support Explained by: Healthy life expectancy  \
# 0                        1,258                                 0,775
# 1                        1,243                                 0,777
# ...

# %%
# Removing everything except the country and Happiness Score
happiness_df.drop(['RANK', 'Whisker-high', 'Whisker-low', 'Dystopia (1.83) + residual', 'Explained by: GDP per capita', 'Explained by: Social support', 'Explained by: Healthy life expectancy', 'Explained by: Freedom to make life choices', 'Explained by: Generosity', 'Explained by: Perceptions of corruption'], axis=1, inplace=True)
happiness_df
# Out:
#          Country Happiness score
# 0        Finland           7,821
# 1        Denmark           7,636
# 2        Iceland           7,557
# 3    Switzerland           7,512
# 4    Netherlands           7,415
# ..           ...             ...
# 142      Rwanda*           3,268
# 143     Zimbabwe           2,995
# 144      Lebanon           2,955
# 145  Afghanistan           2,404
# 146           xx             NaN
#
# [147 rows x 2 columns]

# %%
# Checking for non-numerical 
happiness_df.isnull().sum().sum()
# Out:
# 1
